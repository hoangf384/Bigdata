# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# %%
spark = (
    SparkSession.builder
    .appName("Local-ETL-Test")
    .master("local[*]")
    .config("spark.driver.memory", "2g")
    .config("spark.sql.files.maxPartitionBytes", 256 * 1024 * 1024) # 256 * 1024 * 1024 bytes
    .config("spark.sql.shuffle.partitions", "200") # 200 partitions for shuffle operations
    .getOrCreate()
)
spark.sparkContext.setLogLevel("ERROR")

# %%
df = spark.read.json("/data/destination/log_search/category/*.jsonl")

# %%
df.groupBy("category") \
  .count() \
  .orderBy(F.desc("count")) \
  .show(87, truncate=False)
# Out:
# +-----------------------------------------+------+
# |category                                 |count |
# +-----------------------------------------+------+
# |Other                                    |313962|
# |Drama                                    |57156 |
# |Sports                                   |15306 |
# |Animation                                |14439 |
# |Romance                                  |9569  |
# |Music                                    |8669  |
# |Reality Show                             |4688  |
# |Action                                   |4504  |
# |Horror                                   |3528  |
# |K Drama                                  |1905  |
# |TV Channel                               |1795  |
# |Comedy                                   |1422  |
# |C Drama                                  |1086  |
# |News                                     |1058  |
# |Education                                |27    |
# |Fantasy                                  |13    |
# |Documentary                              |12    |
# |Fantasy/Drama                            |4     |
# |Documentary/Other                        |3     |
# |Education/Other                          |3     |
# |Game                                     |3     |
# |:                                        |2     |
# |Education/Drama                          |2     |
# |Thai Drama                               |2     |
# |Adventure                                |2     |
# |Myth/Drama                               |2     |
# |Mystery                                  |2     |
# |Food/Entertainment                       |1     |
# |Science Fiction; Other                   |1     |
# |Dance/Entertainment; not in list         |1     |
# |Science/Comedy; not in list              |1     |
# |Adventure/Drama                          |1     |
# |Food/Reality; not in list                |1     |
# |Science program, but categorized as Drama|1     |
# |Children/Family                          |1     |
# |Review                                   |1     |
# |Thriller/Drama                           |1     |
# |Travel/Documentary                       |1     |
# |Music/Drama                              |1     |
# |Live Sports                              |1     |
# |Gaming/Other                             |1     |
# |Education/How-To                         |1     |
# |Prayer/Religious                         |1     |
# |Sports/Drama                             |1     |
# |Game/Other                               |1     |
# |Sport                                    |1     |
# |KDrama                                   |1     |
# |Thriller                                 |1     |
# |.Animation                               |1     |
# |Sex/Tantrum                              |1     |
# |Thai                                     |1     |
# |Animation/Drama                          |1     |
# |Reality                                  |1     |
# |Cooking/Reality                          |1     |
# |Technology/Other                         |1     |
# |Live                                     |1     |
# |Dance                                    |1     |
# |Education/Entertainment                  |1     |
# |Food                                     |1     |
# |Educational/Other                        |1     |
# |Mystery/Drama                            |1     |
# |Dance/Reality                            |1     |
# |Family                                   |1     |
# |ScienceFiction                           |1     |
# |Anime                                    |1     |
# +-----------------------------------------+------+

# %%
df = df.withColumn(
    "category_std",
    F.when(F.col("category").rlike("(?i)action"), "Action")
     .when(F.col("category").rlike("(?i)c drama"), "C Drama")
     .when(F.col("category").rlike("(?i)k drama|kdrama"), "K Drama")
     .when(F.col("category").rlike("(?i)drama"), "Drama")
     .when(F.col("category").rlike("(?i)romance"), "Romance")
     .when(F.col("category").rlike("(?i)comedy"), "Comedy")
     .when(F.col("category").rlike("(?i)horror"), "Horror")
     .when(F.col("category").rlike("(?i)animation|anime"), "Animation")
     .when(F.col("category").rlike("(?i)sports|sport"), "Sports")
     .when(F.col("category").rlike("(?i)music"), "Music")
     .when(F.col("category").rlike("(?i)reality"), "Reality Show")
     .when(F.col("category").rlike("(?i)tv|channel"), "TV Channel")
     .when(F.col("category").rlike("(?i)news"), "News")
     .otherwise("Other")
)
